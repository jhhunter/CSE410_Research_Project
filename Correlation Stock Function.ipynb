# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
start = '2013-01-01'
end = '2015-01-01'


def getstock(stock,lst):
    l = []
    a1 = get_pricing(stock, fields='price', start_date=start, end_date=end)
    for tick in lst:
        a2 = get_pricing(tick, fields='price', start_date=start, end_date=end)
        l.append({stock:{tick:np.corrcoef(a1,a2)[0,1]}})
    print(l)
getstock("AAPL",["QCOM","SPY"])

#getstock("AAPL",[QCOM])
data = np.random.rand(4, 6)
#print(data)
heat_map = sb.heatmap([[0.7085370707295639,0.907839467894601]])
plt.show()
# Out:
# [{'AAPL': {'QCOM': 0.70853707072956396}}, {'AAPL': {'SPY': 0.9078394678946019}}]
